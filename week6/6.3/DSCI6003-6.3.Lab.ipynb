# %%
import numpy as np
import sklearn
from sklearn.datasets import make_classification
from scipy.stats import multivariate_normal 
import pylab

# %matplotlib inline

# Question 1: using the template below, write a class that implements as Gaussian Mixture mode
def GaussianMixture(object):
    def __init__(self, k, initial_means, initial_covs):
        self.k = k
        self.means = initial_means
        self.covs = initial_covs
        self.norms = [None]*k
        self._update_norms()
        self.weights = [1./k]*k
        
    def _update_norms(self):
        for index in range(k):
            self.norms[index] = multivariate_normal(mean = self.means[index], 
                                                    cov = self.covs[index])
            
    def _expectation():
        
        
        
        pass
    
    def _maximization():
        pass
    
    def _responsibilities(X):
        pass
    
    def _log_likelihood(X):
        pass
    
    def train(X, threshold = .001):
        pass
    
    def predict(X):
        pass
        
        
# Question 2: Use the GaussianMixture you just defined to make predictions for this data.
X, y = sklearn.datasets.make_classification(n_samples=100, n_features=2, n_redundant=0, 
                                            n_informative=2, random_state=0)

pylab.scatter(X[y==0,0], X[y==0,1], color = 'red')
pylab.scatter(X[y==1,0], X[y==1,1], color = 'blue')
